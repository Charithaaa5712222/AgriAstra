# %%
import pandas as pd

df = pd.read_csv('/content/satellite_dataset.csv')

df.head()
# Out:
#    system:index      NDVI      NDWI  \
# 0             0  0.348767 -0.476177
# 1             1  0.641812 -0.498966
# 2             2  0.826490 -0.700789
# 3             3  0.778754 -0.679737
# 4             4  0.401090 -0.466092
#
#                                                 .geo
# 0  {"type":"Point","coordinates":[79.221722504579...
# 1  {"type":"Point","coordinates":[79.310390943453...
# 2  {"type":"Point","coordinates":[79.347911246388...
# 3  {"type":"Point","coordinates":[79.296441849472...
# 4  {"type":"Point","coordinates":[79.262416130511...

# %%
df.shape
# Out:
# (500, 4)

# %%
df.columns
# Out:
# Index(['system:index', 'NDVI', 'NDWI', '.geo'], dtype='object')

# %%
df.isnull().sum()
# Out:
# system:index    0
# NDVI            0
# NDWI            0
# .geo            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# system:index      int64
# NDVI            float64
# NDWI            float64
# .geo             object
# dtype: object

# %%
df = df.drop(columns=['system:index'])

df.head()
# Out:
#        NDVI      NDWI                                               .geo
# 0  0.348767 -0.476177  {"type":"Point","coordinates":[79.221722504579...
# 1  0.641812 -0.498966  {"type":"Point","coordinates":[79.310390943453...
# 2  0.826490 -0.700789  {"type":"Point","coordinates":[79.347911246388...
# 3  0.778754 -0.679737  {"type":"Point","coordinates":[79.296441849472...
# 4  0.401090 -0.466092  {"type":"Point","coordinates":[79.262416130511...

# %%
df['NDVI'].describe()
# Out:
# count    500.000000
# mean       0.511452
# std        0.267414
# min       -0.541726
# 25%        0.277854
# 50%        0.524586
# 75%        0.776746
# max        0.878077
# Name: NDVI, dtype: float64

# %%
df['NDWI'].describe()
# Out:
# count    500.000000
# mean      -0.507637
# std        0.211502
# min       -0.777235
# 25%       -0.669441
# 50%       -0.538030
# 75%       -0.408049
# max        0.688162
# Name: NDWI, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.hist(df['NDVI'])

plt.title('NDVI Distribution')

plt.xlabel('NDVI')

plt.ylabel('Frequency')

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df['NDWI'])

plt.title('NDWI Distribution')

plt.xlabel('NDWI')

plt.ylabel('Frequency')

plt.show()

# %%
df.to_csv('cleaned_satellite_dataset.csv', index=False)

print("Cleaned dataset saved successfully.")
# Out:
# Cleaned dataset saved successfully.
